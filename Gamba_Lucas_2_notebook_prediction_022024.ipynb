# %% [markdown]
# **Modélisation de la consommation des bâtiments non-résidentiels dans la ville de Seattle.**

# %% [markdown]
# # Dataframe import

# %% [markdown]
# Importons les librairies de base pour la manipulation des données.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Puis importons le dataframe travaillé dans la partie analyse exploratoire.

# %%
path ='/content/drive/MyDrive/FORMATION DATASCIENTIST OC - Lucas GAMBA/Projet 4/Content/df_feat.csv'
df_bis_std_enc=pd.read_csv(path,sep=',').drop(['Unnamed: 0'], axis=1)

# %% [markdown]
# # Feature selection

# %% [markdown]
# Voici les différentes variables regroupées par type :

# %%
# les surfaces
UseType_GFA=['Office',
            'Other',
            'Public_services',
            'Restaurant_hotel_health',
            'Storage',
            'Store']

# les localisations
Neighborhood=['Neighborhood_CENTRAL',
            'Neighborhood_DOWNTOWN',
            'Neighborhood_GREATER DUWAMISH',
            'Neighborhood_NORTH',
            'Neighborhood_SOUTH',
            'Neighborhood_WEST']

Council=['CouncilDistrictCode_1',
       'CouncilDistrictCode_2', 'CouncilDistrictCode_3',
       'CouncilDistrictCode_4', 'CouncilDistrictCode_5',
       'CouncilDistrictCode_6', 'CouncilDistrictCode_7']

Coordinat=['Latitude',
          'Longitude']

# les ratio d'énergie
Ratio_energy=['RatioElectricityUse',
            'RatioSteamUse',
            'RationNaturalGazUse']

# les caractéristiques divers des bâtiments
Property_caract=['PropertyGFABuilding(s)',
                'BuildingAge',
                'NumberofBuildings',
                'NumberofFloors']

# nos targets.
Target_1=['SiteEnergyUseWN(kBtu)']
#Target_2=['TotalGHGEmissions']

# %%
# Features and Targets listes
Features = UseType_GFA + Neighborhood + Council + Coordinat + Ratio_energy + Property_caract
Targets = Target_1

# %% [markdown]
# Nous renommons le dataframe à manipuler :

# %%
# copy in a new dataframe
df_feat = df_bis_std_enc[Features + Targets].copy()

# %%
df_feat.shape
# Out:
# (1470, 29)

# %% [markdown]
# # First modelisation

# %% [markdown]
# Dans cette partie nous allons dans un premier temps tester l'impact de plusieurs types de normalisation de nos variables sur des modèles linéaires simples afin d'établir une première base de l'état d'entrée optimal pour le modèle final.
#
# Dans un second temps nous sélectionnerons un estimateur plus performant sur la base de la première base obtenu.
#
# Enfin nous testerons de nouveau plusieurs configuration d'entrées avec l'estimateur retenons avant d'optiminer ses hyperparamètres pour optenir les meileurs prédictions que possible.

# %%
X = df_feat[Features]
y = df_feat[Targets]

# %% [markdown]
# import des modules nécessaires à lentrainement et validation de modèles, ainsin que des premier estimateurs linéaires à tester.

# %%
# train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2, random_state=100, stratify=pd.qcut(np.array(y).reshape(1,-1)[0], 10))

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet

# %% [markdown]
# La fonction ci-dessous nous permettra de compiler des résultats de gridsearchCV sur plusieurs estimeteurs ce qui nous aidera pour les comparer.

# %%
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.model_selection import GridSearchCV


def Model_Trainer(param_grid, estimators):

  skf = KFold(n_splits=5, shuffle=True, random_state=42)

  result = []
  esti_name = []

  for esti in estimators:
    gridsearch = GridSearchCV(
        esti, param_grid,
        scoring=['neg_root_mean_squared_error','r2'],
        cv=skf.split(X_train,y_train), refit='r2', verbose=0)

    gridsearch.fit(X_train, y_train)

    result.append([gridsearch.best_params_, gridsearch.best_score_])
    esti_name.append(str(esti))

  tab_result = pd.DataFrame(result, columns = ['best_params_', 'best_score_'], index = esti_name)

  return(tab_result)

# %% [markdown]
# ## Model setting

# %% [markdown]
# #### Feature engineering

# %% [markdown]
# Fonctions permettant de faire de la validation croisée sur plusieurs configuration de nos variables d'entrées :

# %%
# fonction qui transforme en std, minmax ou yeo sur colonnes souhaitées
from sklearn.model_selection import cross_validate
from sklearn.compose import ColumnTransformer
from scipy.stats import yeojohnson
from sklearn.preprocessing import MinMaxScaler, StandardScaler


def preprocessing_tsf(col_std, col_mM, col_yeo, X = X, y = y, rd_st=42):
  # pour standardscle et minmax :
  transformer = ColumnTransformer([('Standardscl', StandardScaler(), col_std), ('MinMaxscl', MinMaxScaler(), col_mM)])
  X_encoded = X.copy()
  X_encoded[col_std + col_mM] = pd.DataFrame(transformer.fit_transform(X), columns= [col_std + col_mM], index= X.index)

  # pour yeojohnson
  for col in col_yeo:
    X_encoded[col] = pd.Series(yeojohnson(X_encoded[col])[0],name=col ,index=X_encoded.index)

  X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size = 0.2, random_state = rd_st, stratify = pd.qcut(np.array(y).reshape(1,-1)[0], 10))

  return  X_train, X_test, y_train, y_test

# %%
def Cross_Val_Tab(Estimator, tuple_metrics, Feat_eng_dict, X = X, y = y): #tuple_metrics = ('neg_root_mean_squared_error','r2')

  tab_r  = []

  skf = KFold(n_splits=5, shuffle=True, random_state=42)

  for F in Feat_eng_dict:

    col_std, col_mM, col_yeo = Feat_eng_dict[F]['std'], Feat_eng_dict[F]['Minmax'], Feat_eng_dict[F]['yeojohnson']
    X_train, X_test, y_train, y_test = preprocessing_tsf(col_std, col_mM, col_yeo, X = X, y = y)

    r=cross_validate(Estimator,
                    X_train,
                    y_train,
                    cv = skf.split(X_train,y_train),
                    scoring=tuple_metrics)

    tab_r.append([r['test_' + x].mean() for x in tuple_metrics])

  tab_r_1 = pd.DataFrame(tab_r, columns = [tuple_metrics[x] for x in range(len(tuple_metrics))], index=[F for F in Feat_eng_dict])

  return tab_r_1

# %% [markdown]
# La cellule suivante teste toutes les transforlations spécifiées dans le dictionnaire suivant.
#
# Pou chaque index featuring, la fonction effectue un validation croisé pour l'estimateur donné en commençant par normaliser les variables par trois méthodes différentes (variables à répartir pour chaque méthode) :
#
#
#
# *   "std" pour une Standard Deviation
# *   "Minmax" pour un MinMaxScaler
# *   "yeojohnson" pour une normalisation de yeojohnson.

# %%
Feat_eng_dict = {
    'Featuring 1': {
        'std': ['RatioSteamUse', 'RatioElectricityUse', 'PropertyGFABuilding(s)', 'BuildingAge', 'NumberofFloors'],
        'Minmax': [],
        'yeojohnson': []
    },
    'Featuring 2': {
        'std': [],
        'Minmax': ['RatioSteamUse', 'RatioElectricityUse', 'PropertyGFABuilding(s)', 'BuildingAge', 'NumberofFloors'],
        'yeojohnson': []
    },
    'Featuring 3': {
        'std': [],
        'Minmax': [],
        'yeojohnson': ['RatioSteamUse', 'RatioElectricityUse', 'PropertyGFABuilding(s)', 'BuildingAge', 'NumberofFloors']
    },
    'Featuring 4': {
        'std': [],
        'Minmax': [],
        'yeojohnson': []
    },
    'Featuring 5': {
        'std': ['Office', 'Other', 'Public_services', 'Restaurant_hotel_health',
       'Storage', 'Store'],
        'Minmax': [],
        'yeojohnson': []
    },
    'Featuring 6': {
        'std': [],
        'Minmax': ['Office', 'Other', 'Public_services', 'Restaurant_hotel_health',
       'Storage', 'Store'],
        'yeojohnson': []
    },
    'Featuring 7': {
        'std': [],
        'Minmax': [],
        'yeojohnson': ['Office', 'Other', 'Public_services', 'Restaurant_hotel_health',
       'Storage', 'Store']
    },
    'Featuring 8': {
        'std': ['RatioSteamUse', 'RatioElectricityUse', 'PropertyGFABuilding(s)', 'BuildingAge', 'NumberofFloors'],
        'Minmax': ['Office', 'Other', 'Public_services', 'Restaurant_hotel_health',
       'Storage', 'Store'],
        'yeojohnson': []
    },
    'Featuring 9': {
        'std': ['RatioSteamUse', 'RatioElectricityUse', 'PropertyGFABuilding(s)', 'BuildingAge', 'NumberofFloors'],
        'Minmax': ['Office', 'Other', 'Public_services', 'Restaurant_hotel_health',
       'Storage', 'Store'],
        'yeojohnson': []
    },
    'Featuring 10': {
        'std': ['RatioSteamUse', 'RatioElectricityUse', 'PropertyGFABuilding(s)', 'BuildingAge', 'NumberofFloors'],
        'Minmax': [],
        'yeojohnson': ['Office', 'Other', 'Public_services', 'Restaurant_hotel_health',
       'Storage', 'Store']
    },
    'Featuring 11': {
        'std': [],
        'Minmax': ['RatioSteamUse', 'RatioElectricityUse', 'PropertyGFABuilding(s)', 'BuildingAge', 'NumberofFloors'],
        'yeojohnson': ['Office', 'Other', 'Public_services', 'Restaurant_hotel_health',
       'Storage', 'Store']
    },
    'Featuring 12': { #'RatioElectricityUse', 'PropertyGFABuilding(s)', 'BuildingAge', 'NumberofFloors'
        'std': ['PropertyGFABuilding(s)'],
        'Minmax': ['NumberofFloors', 'BuildingAge'],
        'yeojohnson': ['Office', 'Other', 'Public_services', 'Restaurant_hotel_health',
       'Storage', 'Store','RatioElectricityUse']
    },
    'Featuring 13': { #'RatioElectricityUse', 'PropertyGFABuilding(s)', 'BuildingAge', 'NumberofFloors'
        'std': [],
        'Minmax': ['NumberofFloors', 'BuildingAge', 'PropertyGFABuilding(s)'],
        'yeojohnson': ['Office', 'Other', 'Public_services', 'Restaurant_hotel_health',
       'Storage', 'Store']
    },
    'Featuring 14': { #'RatioElectricityUse', 'PropertyGFABuilding(s)', 'BuildingAge', 'NumberofFloors'
        'std': ['PropertyGFABuilding(s)'],
        'Minmax': ['NumberofFloors', 'BuildingAge'],
        'yeojohnson': ['Office', 'Other', 'Public_services', 'Restaurant_hotel_health',
       'Storage', 'Store','RatioElectricityUse', 'RatioSteamUse']
    },
    'Featuring 15': { #'RatioElectricityUse', 'PropertyGFABuilding(s)', 'BuildingAge', 'NumberofFloors'
        'std': ['PropertyGFABuilding(s)'],
        'Minmax': ['NumberofFloors', 'BuildingAge'],
        'yeojohnson': ['Other', 'BuildingAge', 'Restaurant_hotel_health',
       'Storage','RatioElectricityUse', 'BuildingAge']
    }
}

# normalisation de la target
y_copy = StandardScaler().fit_transform(y.copy())

# autre process particuliers sur X :
X_copy = X.copy()

TABLE_1 = Cross_Val_Tab(Ridge(), ('neg_root_mean_squared_error','r2'), Feat_eng_dict, X_copy, y_copy)
TABLE_1_bis = Cross_Val_Tab(Lasso(), ('neg_root_mean_squared_error','r2'), Feat_eng_dict, X_copy, y_copy)
TABLE_1_bis2 = Cross_Val_Tab(ElasticNet(), ('neg_root_mean_squared_error','r2'), Feat_eng_dict, X_copy, y_copy)
TABLE_1_bis3 = Cross_Val_Tab(LinearRegression(), ('neg_root_mean_squared_error','r2'), Feat_eng_dict, X_copy, y_copy)

print((TABLE_1+TABLE_1_bis+TABLE_1_bis2+TABLE_1_bis3)/4)
# Out:
#               neg_root_mean_squared_error        r2
# Featuring 1                     -0.674111  0.290478
# Featuring 2                     -0.685466  0.260089
# Featuring 3                     -0.750748  0.137817
# Featuring 4                     -0.560298  0.522515
# Featuring 5                     -0.560359  0.522380
# Featuring 6                     -0.559931  0.523308
# Featuring 7                     -0.558894  0.525351
# Featuring 8                     -0.673746  0.291265
# Featuring 9                     -0.673746  0.291265
# Featuring 10                    -0.672710  0.293306
# Featuring 11                    -0.684199  0.262615
# Featuring 12                    -0.670331  0.299448
# Featuring 13                    -0.681930  0.269180
# Featuring 14                    -0.671398  0.296622
# Featuring 15                    -0.670292  0.299125

# %%
plt.bar(data= (TABLE_1+TABLE_1_bis+TABLE_1_bis2+TABLE_1_bis3)/4,
        x= ((TABLE_1+TABLE_1_bis+TABLE_1_bis2+TABLE_1_bis3)/4).index,
        height='r2')
plt.xticks(rotation= 90)
plt.ylabel('r2 score')
plt.xlabel('Feature engineering configuration names')
plt.title('Mean scores on LinearRegression, Lasso, Ridge, ElasticNet')
# Out:
# Text(0.5, 1.0, 'Mean scores on LinearRegression, Lasso, Ridge, ElasticNet')

# %% [markdown]
# ### Best estimators

# %% [markdown]
# Les configuration de 4 à 7 donnes les meilleurs résultats tout modèle confondu. Le 7 est légèrement meilleur.

# %% [markdown]
# Nous allons maintenant comparer trois autre estimateurs sur la base du feature engineering suivant.

# %%
# Featuring 7
col_std, col_mM, col_yeo = [], [], ['Office', 'Other', 'Public_services', 'Restaurant_hotel_health',
       'Storage', 'Store']

X_train, X_test, y_train, y_test = preprocessing_tsf(col_std, col_mM, col_yeo)

# %%
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from xgboost import XGBRegressor

model_grid = [
    {
        'model__estimator': [
            RandomForestRegressor(),
            GradientBoostingRegressor(),
            XGBRegressor()
        ],
        'param_grid': {
              'n_estimators' : [int(x) for x in np.linspace(start=100, stop=300,num=3)],
              'max_features' : ['auto','sqrt'],
              'max_depth' : [5, 10, 20],
        }
    }]

tab_result = pd.DataFrame()

for mod in model_grid:
  tab_result = pd.concat([tab_result, Model_Trainer(mod['param_grid'], mod['model__estimator'])], axis = 0)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# ...
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# [12:52:54] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:52:54] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:52:55] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:52:55] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:52:55] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:52:55] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:52:55] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:52:55] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:52:56] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:52:56] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:52:56] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:52:56] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:52:57] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:52:57] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:52:57] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:52:58] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:52:58] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:52:58] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:52:58] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:52:58] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:52:58] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:52:58] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:52:59] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:52:59] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:52:59] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:52:59] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:00] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:01] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:01] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:02] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:02] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:02] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:03] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:03] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:04] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:04] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:05] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:06] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:07] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:08] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:09] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:10] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:11] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:13] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:14] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:15] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:16] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:16] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:17] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:17] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:18] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:19] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:20] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:20] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:21] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:22] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:24] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:26] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:27] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:28] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:29] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:30] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:32] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:33] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:36] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:37] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:40] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:42] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:45] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:48] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:51] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:55] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:53:59] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:54:03] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:54:07] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:54:11] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:54:13] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:54:14] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:54:16] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:54:17] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:54:19] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:54:22] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:54:24] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:54:27] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:54:30] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:54:33] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:54:37] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:54:40] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:54:45] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:54:49] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.
#
# [12:54:52] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "max_features" } are not used.

# %%
tab_result
# Out:
#                                                                                          best_params_  \
# RandomForestRegressor()                             {'max_depth': 10, 'max_features': 'auto', 'n_e...
# GradientBoostingRegressor()                         {'max_depth': 5, 'max_features': 'sqrt', 'n_es...
# XGBRegressor(base_score=None, booster=None, cal...  {'max_depth': 5, 'max_features': 'auto', 'n_es...
#
#                                                     best_score_
# RandomForestRegressor()                                0.670328
# GradientBoostingRegressor()                            0.690911
# XGBRegressor(base_score=None, booster=None, cal...     0.622700

# %%
plt.bar(data= tab_result,
        x= ['Gridsearch 1', 'Gridsearch 2', 'Gridsearch 3'],
        height='best_score_')
plt.xticks(rotation= 90)
plt.ylabel('best r2 score')
plt.xlabel('Model GridSearchCV index')
plt.title('Best CV scores got with\nRandomForestRegressor, GradientBoostingRegressor and XGBRegressor')
# Out:
# Text(0.5, 1.0, 'Best CV scores got with\nRandomForestRegressor, GradientBoostingRegressor and XGBRegressor')

# %% [markdown]
# Le gradient boosting donne les meilleurs scores en moyenne avec le paramètrage ci-dessous :

# %%
tab_result.iloc[1,0]
# Out:
# {'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200}

# %% [markdown]
# ### Validation curve

# %% [markdown]
# Nous allons maintenant optimiser le nombre d'estimateurs sur ce paramèrage.

# %%
from sklearn.model_selection import validation_curve
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor

def validation_curve_(model,hyperparam,param_range,cv, X_train= X_train, y_train= y_train):
  train_score, val_score = validation_curve(model, X_train, y_train,
                                             param_name = hyperparam, param_range = param_range, cv = cv)

  plt.plot(param_range, val_score.mean(axis=1), label='validation')
  plt.plot(param_range, train_score.mean(axis=1), label='train')

  plt.ylabel('score')
  plt.xlabel(hyperparam)
  plt.grid()
  plt.legend()

# %%
skf = KFold(n_splits=5, shuffle=True, random_state=42)

validation_curve_(model = GradientBoostingRegressor(max_depth = 5,
                                              max_features = 'sqrt'),
                  hyperparam = 'n_estimators',
                  param_range = np.arange(10,1000,100),
                  cv = skf.split(X_train,y_train))
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %% [markdown]
# Visiblement le score atteint un maximum à partir d'un nombre d'estimateurs autour de 500.
#
# On peut cependant noter que le modèle overfit car l'écart entre les scores sur les sets d'entraînement et de validation est assez important.

# %% [markdown]
# ## Model evalution on testset

# %% [markdown]
# Evaluons notre modèle sur le set de test.

# %%
model_ = GradientBoostingRegressor(max_depth = 5,
                                  max_features = 'sqrt',
                                  n_estimators=500)
model_.fit(X_train, y_train) #.drop(['RationNaturalGazUse', 'Storage'], axis=1)
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# GradientBoostingRegressor(max_depth=5, max_features='sqrt', n_estimators=400)

# %%
model_.score(X_test, y_test), model_.score(X_train, y_train)
# Out:
# (0.5786909207631492, 0.9987030135580351)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error

y_pred=model_.predict(X_test)#model_.predict(X.loc[y_test.index,:])
S1=pd.Series(y_pred.reshape(1,-1)[0])
S2=pd.Series(np.array(y_test).reshape(1,-1)[0])
pears=pd.concat([S1,S2], axis=1, ignore_index=True).corr().iloc[1,0]

sns.regplot(x=y_pred,y=np.array(y_test).reshape(1,-1)[0])
plt.xlabel('y_pred')
plt.ylabel('y_test')
plt.text(x=np.median(y_pred),y=np.median(y_test),s=f'R² = {str(round(pears,2))}')
# Out:
# Text(3769538.291688286, 2778827.25, 'R² = 0.76')

# %%
MSE = mean_squared_error(np.array(y_test).reshape(1,-1)[0],np.array(y_pred).reshape(1,-1)[0])
r2 = r2_score(np.array(y_test).reshape(1,-1)[0],np.array(y_pred).reshape(1,-1)[0])
MAPE = mean_absolute_percentage_error(np.array(y_test).reshape(1,-1)[0],np.array(y_pred).reshape(1,-1)[0])

print(f'r2_score : {round(r2,2)}\n',
      f'mean_absolute_percentage_error : {round(MAPE*100,2)} %\n',
      f'coef pearson btw predict and true : {round(pears,2)}')
# Out:
# r2_score : 0.58
#  mean_absolute_percentage_error : 128.5 %
#  coef pearson btw predict and true : 0.76

# %% [markdown]
# Les résultats ne sont pas encore très bons.

# %% [markdown]
# ## Feature importance

# %% [markdown]
# ### Permutation importance

# %% [markdown]
# Nous pouvons faire une première analyse des variables importantes pour le modèle avec SHAP en comparaison avec celles qui sont les plus exploitées par le modèle via la méthode feature_importance_.

# %%
from sklearn.inspection import permutation_importance

# %%
feature_importance = model_.feature_importances_

sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + 0.5
fig = plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.barh(pos, feature_importance[sorted_idx], align="center")
plt.yticks(pos, np.array(X_test.columns)[sorted_idx])
plt.title("Feature Importance (MDI)")


result = permutation_importance(
    model_, X_train, y_train, n_repeats=10, random_state=42, n_jobs=2,
    scoring = ['r2', 'neg_mean_squared_error']
) #.drop(['RationNaturalGazUse', 'Storage'], axis=1)

sorted_idx_r2 = result['r2']['importances_mean'].argsort()
plt.subplot(1, 2, 2)
plt.boxplot(
    result['r2']['importances'][sorted_idx_r2].T,
    vert=False,
    labels=np.array(X_test.columns)[sorted_idx_r2],
)
plt.title("Permutation Importance (test set) r2")

fig.tight_layout()
plt.show()

# %% [markdown]
# ### SHAP analysis

# %%
pip install shap
# Out:
# Requirement already satisfied: shap in /usr/local/lib/python3.10/dist-packages (0.44.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.11.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.3)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.66.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (23.2)
# Requirement already satisfied: slicer==0.0.7 in /usr/local/lib/python3.10/dist-packages (from shap) (0.0.7)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.58.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.41.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2023.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %%
explainer = shap.Explainer(model_)
shape_values = explainer(X_train) #.drop(['RationNaturalGazUse', 'Storage'], axis=1)

# %%
shap.plots.bar(shape_values, max_display=20)

# %%
shap.plots.beeswarm(shape_values)

# %% [markdown]
# D'après les différences entre le feature importance et le shap importance, le modèle semble overfitter avec NumberofBuilding, Latitude et RatioNaturalGazUse.

# %% [markdown]
# # Model and feature setting

# %% [markdown]
# ## Feature engineering large

# %% [markdown]
# Nous allons maintenant balayer un grand nombre de configuration d'entrées avec notre estimateur pour trouver celles qui optimise le mieux ses performances.

# %%
Feat_eng_dict = {
    'Featuring 4': {
        'std': [],
        'Minmax': [],
        'yeojohnson': []
    },
    'Featuring 5': {
        'std': ['Office', 'Other', 'Public_services', 'Restaurant_hotel_health',
       'Storage', 'Store'],
        'Minmax': [],
        'yeojohnson': []
    },
    'Featuring 6': {
        'std': [],
        'Minmax': ['Office', 'Other', 'Public_services', 'Restaurant_hotel_health',
       'Storage', 'Store'],
        'yeojohnson': []
    },
    'Featuring 7': {
        'std': [],
        'Minmax': [],
        'yeojohnson': ['Office', 'Other', 'Public_services', 'Restaurant_hotel_health',
       'Storage', 'Store']
    },
    'Featuring 1b': {
        'std': ['RatioSteamUse', 'RatioElectricityUse', 'PropertyGFABuilding(s)', 'BuildingAge', 'NumberofFloors'],
        'Minmax': [],
        'yeojohnson': []
    },
    'Featuring 2b': {
        'std': ['Office', 'Other', 'Public_services', 'Restaurant_hotel_health',
       'Storage', 'Store'],
        'Minmax': [],
        'yeojohnson': []
    },
    'Featuring 3b': {
        'std': [],
        'Minmax': [],
        'yeojohnson': ['Office', 'Other', 'Public_services', 'Restaurant_hotel_health',
       'Storage', 'Store']
    },
    'Featuring 4b': {
        'std': ['RatioSteamUse', 'RatioElectricityUse', 'PropertyGFABuilding(s)', 'BuildingAge', 'NumberofFloors'],
        'Minmax': ['Office', 'Other', 'Public_services', 'Restaurant_hotel_health',
       'Storage', 'Store'],
        'yeojohnson': []
    },
    'Featuring 5b': {
        'std': ['RatioSteamUse', 'RatioElectricityUse', 'PropertyGFABuilding(s)', 'BuildingAge', 'NumberofFloors'],
        'Minmax': ['Office', 'Other', 'Public_services', 'Restaurant_hotel_health',
       'Storage', 'Store'],
        'yeojohnson': []
    },
    'Featuring 6b': {
        'std': ['RatioSteamUse', 'RatioElectricityUse', 'PropertyGFABuilding(s)', 'BuildingAge', 'NumberofFloors'],
        'Minmax': [],
        'yeojohnson': ['Office', 'Other', 'Public_services', 'Restaurant_hotel_health',
       'Storage', 'Store']
    },
    'Featuring 7b': {
        'std': [],
        'Minmax': ['RatioSteamUse', 'RatioElectricityUse', 'PropertyGFABuilding(s)', 'BuildingAge', 'NumberofFloors'],
        'yeojohnson': ['Office', 'Other', 'Public_services', 'Restaurant_hotel_health',
       'Storage', 'Store']
    },
    'Featuring 8b': { #'RatioElectricityUse', 'PropertyGFABuilding(s)', 'BuildingAge', 'NumberofFloors'
        'std': [],
        'Minmax': ['NumberofFloors', 'BuildingAge', 'PropertyGFABuilding(s)'],
        'yeojohnson': ['Office', 'Other', 'Public_services', 'Restaurant_hotel_health',
       'Storage', 'Store']
    },
    'Featuring 9b': { #'RatioElectricityUse', 'PropertyGFABuilding(s)', 'BuildingAge', 'NumberofFloors'
        'std': ['PropertyGFABuilding(s)'],
        'Minmax': ['NumberofFloors', 'BuildingAge'],
        'yeojohnson': ['Other', 'BuildingAge', 'Restaurant_hotel_health',
       'Storage','RatioElectricityUse', 'BuildingAge']
    }
}

# normalisation de la target
y_copy = StandardScaler().fit_transform(y.copy())

# autre process particuliers sur X :
X_copy = X.copy()


TABLE_2 = Cross_Val_Tab(model_, ('neg_root_mean_squared_error','r2'), Feat_eng_dict, X_copy, y_copy)
TABLE_2
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#               neg_root_mean_squared_error        r2
# Featuring 4                     -0.448775  0.705155
# Featuring 5                     -0.462340  0.673118
# Featuring 6                     -0.463588  0.682154
# Featuring 7                     -0.454174  0.695197
# Featuring 1b                    -0.477096  0.667432
# Featuring 2b                    -0.486402  0.650533
# Featuring 3b                    -0.463190  0.673813
# Featuring 4b                    -0.480321  0.658538
# Featuring 5b                    -0.489212  0.647214
# Featuring 6b                    -0.453619  0.688791
# Featuring 7b                    -0.465725  0.671731
# Featuring 8b                    -0.455910  0.701065
# Featuring 9b                    -0.467614  0.680544

# %% [markdown]
# En faisant une seconde cross validation du meilleur modèle en reprenant les configurations de feature engineering précédentes et de nouvelles configuration nous obtenons tout de même un score de 0.7 sur les configuration 6, 5b et 8b.

# %% [markdown]
# ## Feature engineering ajusted

# %% [markdown]
# Nous allons reprendre les configuration qui marchent le mieux et rajouter quelques transformations mannuellement sur les features et sur la target pour voir s'il est possible d'obtnir de meilleurs scores.

# %%
Feat_eng_dict = {
    'Featuring 6': {
        'std': [],
        'Minmax': ['Office', 'Other', 'Public_services', 'Restaurant_hotel_health',
       'Storage', 'Store'],
        'yeojohnson': []
    },
    'Featuring 5b': {
        'std': ['RatioSteamUse', 'RatioElectricityUse', 'PropertyGFABuilding(s)', 'BuildingAge', 'NumberofFloors'],
        'Minmax': ['Office', 'Other', 'Public_services', 'Restaurant_hotel_health',
       'Storage', 'Store'],
        'yeojohnson': []
    },
    'Featuring 8b': { #'RatioElectricityUse', 'PropertyGFABuilding(s)', 'BuildingAge', 'NumberofFloors'
        'std': [],
        'Minmax': ['NumberofFloors', 'BuildingAge', 'PropertyGFABuilding(s)'],
        'yeojohnson': ['Office', 'Other', 'Public_services', 'Restaurant_hotel_health',
       'Storage', 'Store']
    },
    'Featuring 5b_2': {
        'std': ['RatioSteamUse', 'RatioElectricityUse', 'BuildingAge', 'NumberofFloors', 'RationNaturalGazUse'],
        'Minmax': ['Office', 'Other', 'Public_services', 'Restaurant_hotel_health',
       'Storage', 'Store'],
        'yeojohnson': ['PropertyGFABuilding(s)', 'NumberofBuildings', 'Latitude', 'Longitude']
    },
    'Featuring 9b': { # yeojohnson sur les plus important selon SHAP
        'std': [],
        'Minmax': [],
        'yeojohnson': ['RatioSteamUse', 'Storage', 'Office', 'Other', 'RationNaturalGazUse' ,'RatioElectricityUse', 'BuildingAge', 'NumberofFloors', 'Restaurant_hotel_health', 'PropertyGFABuilding(s)', 'NumberofBuildings', 'Latitude', 'Longitude']
    },
    'Featuring 10b': { # yeojohnson sur les plus important selon SHAP + normalisation latitude/longitude
        'std': [],
        'Minmax': [],
        'yeojohnson': ['Latitude', 'Longitude', 'RatioSteamUse', 'Storage', 'Office', 'Other', 'RationNaturalGazUse' ,'RatioElectricityUse', 'BuildingAge', 'NumberofFloors', 'Restaurant_hotel_health', 'PropertyGFABuilding(s)', 'NumberofBuildings']
    }
}

# %%
# normalisation de la target par yeojohnson
y_copy = pd.Series(yeojohnson(y.copy())[0].reshape(1,-1)[0],name='SiteEnergyUseWN(kBtu)' ,index=y.index) #np.log(y) #StandardScaler().fit_transform(y.copy())

# autre process particuliers sur X :
X_copy = X.copy()

TABLE_3_1 = Cross_Val_Tab(model_, ('neg_root_mean_squared_error','r2'), Feat_eng_dict, X_copy, y_copy)
TABLE_3_1
# Out:
#                 neg_root_mean_squared_error        r2
# Featuring 6                       -0.467404  0.632798
# Featuring 5b                      -0.470134  0.628381
# Featuring 8b                      -0.465357  0.636130
# Featuring 5b_2                    -0.468649  0.630556
# Featuring 9b                      -0.474883  0.620978
# Featuring 10b                     -0.462263  0.641024

# %%
# normalisation de la target par Standard Deviation
y_copy = StandardScaler().fit_transform(y.copy())

# autre process particuliers sur X :
X_copy = X.copy()


TABLE_3_2 = Cross_Val_Tab(model_, ('neg_root_mean_squared_error','r2'), Feat_eng_dict, X_copy, y_copy)
TABLE_3_2
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#                 neg_root_mean_squared_error        r2
# Featuring 6                       -0.455318  0.685462
# Featuring 5b                      -0.443987  0.704368
# Featuring 8b                      -0.461757  0.679030
# Featuring 5b_2                    -0.463198  0.681339
# Featuring 9b                      -0.457101  0.691583
# Featuring 10b                     -0.469388  0.674226

# %%
# normalisation de la target par Standard Scaler
y_copy = StandardScaler().fit_transform(y.copy())

# autre process particuliers sur X :
X_copy = X.copy()
X_copy['RatioElectricityUse'] = X['RatioElectricityUse']/100
X_copy['RatioSteamUse'] = X['RatioSteamUse']/100
X_copy['RationNaturalGazUse'] = X['RationNaturalGazUse']/100


TABLE_3_3 = Cross_Val_Tab(model_, ('neg_root_mean_squared_error','r2'), Feat_eng_dict, X_copy, y_copy)
TABLE_3_3
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#                 neg_root_mean_squared_error        r2
# Featuring 6                       -0.473619  0.670177
# Featuring 5b                      -0.448458  0.695255
# Featuring 8b                      -0.441607  0.707406
# Featuring 5b_2                    -0.477810  0.655988
# Featuring 9b                      -0.446379  0.694684
# Featuring 10b                     -0.457013  0.692505

# %%
# normalisation de la target yeojohnson
y_copy = pd.Series(yeojohnson(y.copy())[0].reshape(1,-1)[0],name='SiteEnergyUseWN(kBtu)' ,index=y.index)

# autre process particuliers sur X :
X_copy = X.copy()
X_copy['RatioElectricityUse'] = X['RatioElectricityUse']/100
X_copy['RatioSteamUse'] = X['RatioSteamUse']/100
X_copy['RationNaturalGazUse'] = X['RationNaturalGazUse']/100


TABLE_3_4 = Cross_Val_Tab(model_, ('neg_root_mean_squared_error','r2'), Feat_eng_dict, X_copy, y_copy)
TABLE_3_4
# Out:
#                 neg_root_mean_squared_error        r2
# Featuring 6                       -0.460849  0.642645
# Featuring 5b                      -0.468380  0.631442
# Featuring 8b                      -0.470269  0.628137
# Featuring 5b_2                    -0.464829  0.637191
# Featuring 9b                      -0.459269  0.645352
# Featuring 10b                     -0.466744  0.634049

# %%
# normalisation de la target
y_copy = pd.Series(yeojohnson(y.copy())[0].reshape(1,-1)[0],name='SiteEnergyUseWN(kBtu)' ,index=y.index)

# autre process particuliers sur X :
X_copy = X.copy()

TABLE_3_5 = Cross_Val_Tab(model_, ('neg_root_mean_squared_error','r2'), Feat_eng_dict, X_copy, y_copy)
TABLE_3_5
# Out:
#                 neg_root_mean_squared_error        r2
# Featuring 6                       -0.465168  0.636010
# Featuring 5b                      -0.468640  0.630800
# Featuring 8b                      -0.462613  0.639785
# Featuring 5b_2                    -0.466999  0.633609
# Featuring 9b                      -0.469215  0.629953
# Featuring 10b                     -0.469660  0.629374

# %% [markdown]
# ## Feature engineering selection

# %% [markdown]
# Parmis les résultats, nous retiendrons la configuration 10b avec yeojohnson sur la target car celle-ci compte un grand nombre de normalisation tout en gardant un score moyen correct.

# %%
# 10b + % ratio + std target

# config 10b
col_std, col_mM, col_yeo =  [],[], ['Latitude', 'Longitude', 'RatioSteamUse', 'Storage', 'Office', 'Other', 'RationNaturalGazUse' ,'RatioElectricityUse', 'BuildingAge', 'NumberofFloors', 'Restaurant_hotel_health', 'PropertyGFABuilding(s)', 'NumberofBuildings']
# normalisation de la target
y_copy = pd.Series(yeojohnson(y.copy())[0].reshape(1,-1)[0],name='SiteEnergyUseWN(kBtu)' ,index=y.index) #StandardScaler().fit_transform(y.copy())

# autre process particuliers sur X :
X_copy = X.copy()
X_copy['RatioElectricityUse'] = X['RatioElectricityUse']/100
X_copy['RatioSteamUse'] = X['RatioSteamUse']/100
X_copy['RationNaturalGazUse'] = X['RationNaturalGazUse']/100

X_train, X_test, y_train, y_test = preprocessing_tsf(col_std, col_mM, col_yeo, X=X_copy, y= y_copy)

# %% [markdown]
# Testons à nouveau le modèle sur le nombre d'estimateurs avec la nouvelle configuration d'entrées.

# %%
skf = KFold(n_splits=5, shuffle=True, random_state=42)

validation_curve_(model = model_,
                  hyperparam = 'n_estimators',
                  param_range = np.arange(10,1000,100),
                  cv = skf.split(X_train,y_train))
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %% [markdown]
# Le modèle a un pique de performance vers n_estimators = 300.

# %%
validation_curve_(model = model_,
                  hyperparam = 'n_estimators',
                  param_range = np.arange(250,350,10),
                  cv = skf.split(X_train,y_train))
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %%
validation_curve_(model = model_,
                  hyperparam = 'n_estimators',
                  param_range = np.arange(300,320,1),
                  cv = skf.split(X_train,y_train))
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %% [markdown]
# Nous retiendrons n_estimators = 312.

# %%
model_ = GradientBoostingRegressor(max_depth = 5,
                                  max_features = 'sqrt',
                                  n_estimators=312)
model_.fit(X_train, y_train) #.drop(['RationNaturalGazUse', 'Storage'], axis=1)
# Out:
# GradientBoostingRegressor(max_depth=5, max_features='sqrt', n_estimators=312)

# %% [markdown]
# ## Feature importance

# %% [markdown]
# Faisons une analyse d'inmportance des variables pour avoir des éléments de comparaisons dans les parties suivantes d'optimisation du modèle.

# %%
explainer = shap.Explainer(model_)
shape_values = explainer(X_train)
shap.plots.bar(shape_values, max_display=20)

# %%
feature_importance = model_.feature_importances_

sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + 0.5
fig = plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.barh(pos, feature_importance[sorted_idx], align="center")
plt.yticks(pos, np.array(X_test.columns)[sorted_idx])
plt.title("Feature Importance (MDI)")


result = permutation_importance(
    model_, X_train, y_train, n_repeats=10, random_state=42, n_jobs=2,
    scoring = ['r2', 'neg_mean_squared_error']
)

sorted_idx_r2 = result['r2']['importances_mean'].argsort()
plt.subplot(1, 2, 2)
plt.boxplot(
    result['r2']['importances'][sorted_idx_r2].T,
    vert=False,
    labels=np.array(X_test.columns)[sorted_idx_r2],
)
plt.title("Permutation Importance (test set) r2")

fig.tight_layout()
plt.show()

# %% [markdown]
# On remarque qu'un certain nombre de variables ne sont pas exploitées par le modèle.
#
# Certaines ne sont (d'après l'analyse SHAP) même pas utiles.

# %% [markdown]
# ## Variable VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def vif_analyse(dataframe, prints=False):

  vif_data=pd.DataFrame()
  vif_data['features']=dataframe.columns
  vif_data['VIF']=[variance_inflation_factor(dataframe.values,i) for i in range(len(dataframe.columns))]

  if prints==True:
    print(vif_data)

  plt.bar(x = vif_data['features'], height = vif_data['VIF'])
  plt.xticks(rotation=90)
  plt.title('VIF analyse')
  plt.grid(axis='y')

  return vif_data

# %%
X_vif = X_copy.copy()
vif_analyse(X_vif)
# Out:
# divide by zero encountered in double_scalars
#                          features        VIF
# 0                          Office   2.634593
# 1                           Other   1.590930
# 2                 Public_services   1.533094
# 3         Restaurant_hotel_health   1.677311
# 4                         Storage   2.034066
# 5                           Store   1.917144
# 6            Neighborhood_CENTRAL        inf
# 7           Neighborhood_DOWNTOWN        inf
# 8   Neighborhood_GREATER DUWAMISH        inf
# 9              Neighborhood_NORTH        inf
# 10             Neighborhood_SOUTH        inf
# 11              Neighborhood_WEST        inf
# 12          CouncilDistrictCode_1        inf
# 13          CouncilDistrictCode_2        inf
# 14          CouncilDistrictCode_3        inf
# 15          CouncilDistrictCode_4        inf
# 16          CouncilDistrictCode_5        inf
# 17          CouncilDistrictCode_6        inf
# 18          CouncilDistrictCode_7        inf
# 19                       Latitude  16.155562
# 20                      Longitude   3.294542
# 21            RatioElectricityUse   5.384656
# 22                  RatioSteamUse   1.130575
# 23            RationNaturalGazUse   5.245282
# 24         PropertyGFABuilding(s)   1.989615
# 25                    BuildingAge   1.267142
# 26              NumberofBuildings   1.133097
# 27                 NumberofFloors   2.180636

# %% [markdown]
# On remarque également certaines fortes corrélations entre nos variables qu'il faudra traiter ultérieurement.

# %% [markdown]
# ## Model testing

# %%
model_.score(X_test, y_test)
# Out:
# 0.7073536105319127

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error

y_pred=model_.predict(X_test)#model_.predict(X.loc[y_test.index,:])
S1=pd.Series(y_pred.reshape(1,-1)[0])
S2=pd.Series(np.array(y_test).reshape(1,-1)[0])
pears=pd.concat([S1,S2], axis=1, ignore_index=True).corr().iloc[1,0]

sns.regplot(x=y_pred,y=np.array(y_test).reshape(1,-1)[0])
plt.xlabel('y_pred')
plt.ylabel('y_test')
plt.text(x=np.median(y_pred),y=np.median(y_test),s=f'R² = {str(round(pears,2))}')
# Out:
# Text(11.512090106401455, 11.537745299998889, 'R² = 0.84')

# %%
MSE = mean_squared_error(np.array(y_test).reshape(1,-1)[0],np.array(y_pred).reshape(1,-1)[0])
r2 = r2_score(np.array(y_test).reshape(1,-1)[0],np.array(y_pred).reshape(1,-1)[0])
MAPE = mean_absolute_percentage_error(np.array(y_test).reshape(1,-1)[0],np.array(y_pred).reshape(1,-1)[0])

print(f'r2_score : {round(r2,2)}\n',
      f'mean_absolute_percentage_error : {round(MAPE*100,2)} %\n',
      f'coef pearson btw predict and true : {round(pears,2)}')
# Out:
# r2_score : 0.71
#  mean_absolute_percentage_error : 2.68 %
#  coef pearson btw predict and true : 0.84

# %% [markdown]
# Les performances sont nettement meilleures.

# %% [markdown]
# ## Learning curve

# %%
# fonction d'évaluation du modele

from sklearn.model_selection import learning_curve # pour visu overfitting
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error # import des metrics
from sklearn.metrics import make_scorer

def evaluation(model,model_name, rdst=42):

  model.fit(X_train, y_train)
  y_pred =  model.predict(X_test)

  N, train_score, val_score = learning_curve(model, X_train, y_train,
						cv=KFold(n_splits=4, shuffle=True, random_state=rdst), scoring = 'r2',
						train_sizes=np.linspace(0.1, 1, 10))
  plt.figure(figsize=(10,6))
  plt.title(model_name)
  plt.plot(N, train_score.mean(axis=1), label='train score')
  #évolution du train_score en fonction du nombre d'échantillons qui ont servi à l'entraînement
  plt.plot(N, val_score.mean(axis=1), label='validation score')
  plt.xlabel('Qté de données')
  plt.ylabel('Score R²')
  plt.grid()
  plt.legend()

# %%
evaluation(model_,'model_')

# %% [markdown]
# Il semblerait qu'avec une plus grande quantité de données nous pourrions optimiser d'avantage les performance du modèle.
#
# Néanmoins, nous avons tout de même de l'overfitting sur les données d'entraînements d'après la learning curve.

# %% [markdown]
# # Feature removed

# %% [markdown]
# Nous avons vu que les coordonnées géographiques perturbent nos entrées d'près l'analyse VIF précédente.
#
# De même pour les quartiers.
#
# Ainsi nous pourrions supprimer une partie des entrées de localisation qui ne sont pas ou peu utilisées par le modèle dans les prédictions.

# %%
X_copy=X.copy()
X_vif = X_copy.copy().drop(Neighborhood + ['CouncilDistrictCode_1', 'Longitude', 'Latitude'], axis = 1)
vif_analyse(X_vif) #, prints=False  Neighborhood +
# Out:
#                    features        VIF
# 0                    Office   4.277920
# 1                     Other   1.682795
# 2           Public_services   1.587035
# 3   Restaurant_hotel_health   1.746630
# 4                   Storage   2.263964
# 5                     Store   2.187916
# 6     CouncilDistrictCode_2   2.285286
# 7     CouncilDistrictCode_3   4.397163
# 8     CouncilDistrictCode_4   2.618266
# 9     CouncilDistrictCode_5   5.744817
# 10    CouncilDistrictCode_6   2.063736
# 11    CouncilDistrictCode_7   1.866429
# 12      RatioElectricityUse  16.307583
# 13            RatioSteamUse   1.155494
# 14      RationNaturalGazUse   4.431230
# 15   PropertyGFABuilding(s)   2.674492
# 16              BuildingAge   4.124744
# 17        NumberofBuildings   4.623690
# 18           NumberofFloors   2.818871
# 19          ENERGYSTARScore   9.164182

# %% [markdown]
# Les résultats VIF sont meilleurs.

# %% [markdown]
# Réentraînons lemodèle sur cette nouvelle base en adaptant la configuration d'entrée 10b élaborées précédemment.

# %%
# 10b + % ratio + std target + suppression des features après analyse VIF

# config 10b
col_std, col_mM, col_yeo =  [],[], ['RationNaturalGazUse', 'RatioSteamUse', 'Storage', 'Office', 'Other', 'RatioElectricityUse', 'BuildingAge', 'NumberofFloors', 'Restaurant_hotel_health', 'PropertyGFABuilding(s)', 'NumberofBuildings']
# normalisation de la target
y_copy = pd.Series(yeojohnson(y.copy())[0].reshape(1,-1)[0],name='SiteEnergyUseWN(kBtu)' ,index=y.index) #StandardScaler().fit_transform(y.copy())

# autre process particuliers sur X :
X_copy = X.copy()
X_copy = X_copy.drop(Neighborhood + ['CouncilDistrictCode_1', 'Longitude', 'Latitude'], axis = 1)
X_copy['RatioElectricityUse'] = X['RatioElectricityUse']/100
X_copy['RatioSteamUse'] = X['RatioSteamUse']/100
X_copy['RationNaturalGazUse'] = X['RationNaturalGazUse']/100

X_train, X_test, y_train, y_test = preprocessing_tsf(col_std, col_mM, col_yeo, X=X_copy, y= y_copy)

# %%
skf = KFold(n_splits=5, shuffle=True, random_state=42)

validation_curve_(model = model_,
                  hyperparam = 'n_estimators',
                  param_range = np.arange(10,1000,100),
                  cv = skf.split(X_train,y_train))
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %%
validation_curve_(model = model_,
                  hyperparam = 'n_estimators',
                  param_range = np.arange(510,530,1),
                  cv = skf.split(X_train,y_train))
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %% [markdown]
# Nous retiendrons n_estimators = 516.

# %%
model_ = GradientBoostingRegressor(max_depth = 5,
                                  max_features = 'sqrt',
                                  n_estimators=516)
model_.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(max_depth=5, max_features='sqrt', n_estimators=516)

# %%
model_.score(X_test, y_test)
# Out:
# 0.6673681319450953

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error

y_pred=model_.predict(X_test)#model_.predict(X.loc[y_test.index,:])
S1=pd.Series(y_pred.reshape(1,-1)[0])
S2=pd.Series(np.array(y_test).reshape(1,-1)[0])
pears=pd.concat([S1,S2], axis=1, ignore_index=True).corr().iloc[1,0]

sns.regplot(x=y_pred,y=np.array(y_test).reshape(1,-1)[0])
plt.xlabel('y_pred')
plt.ylabel('y_test')
plt.text(x=np.median(y_pred),y=np.median(y_test),s=f'R² = {str(round(pears,2))}')
# Out:
# Text(11.498410696972707, 11.537745299998889, 'R² = 0.82')

# %%
MSE = mean_squared_error(np.array(y_test).reshape(1,-1)[0],np.array(y_pred).reshape(1,-1)[0])
r2 = r2_score(np.array(y_test).reshape(1,-1)[0],np.array(y_pred).reshape(1,-1)[0])
MAPE = mean_absolute_percentage_error(np.array(y_test).reshape(1,-1)[0],np.array(y_pred).reshape(1,-1)[0])

print(f'r2_score : {round(r2,2)}\n',
      f'mean_absolute_percentage_error : {round(MAPE*100,2)} %\n',
      f'coef pearson btw predict and true : {round(pears,2)}')
# Out:
# r2_score : 0.67
#  mean_absolute_percentage_error : 2.81 %
#  coef pearson btw predict and true : 0.82

# %%
evaluation(model_,'model_')

# %% [markdown]
# Les performances sont sensiblement les mêmes après suppression de ces éléments.

# %% [markdown]
# # EnergyStarScore influence

# %% [markdown]
# Voyons maintenant l'influence de l'EnergyStarSCore

# %%
df_source=pd.read_csv('/content/drive/MyDrive/FORMATION DATASCIENTIST OC - Lucas GAMBA/Projet 4/Content/2016_Building_Energy_Benchmarking.csv',sep=',')

# %% [markdown]
# ## Imputation NaN

# %%
plt.boxplot(df_source['ENERGYSTARScore'].dropna(), labels=['ENERGYSTARScore'], showmeans=True, showfliers=True,patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7bf4985eaec0>,
#   <matplotlib.lines.Line2D at 0x7bf4985eae30>],
#  'caps': [<matplotlib.lines.Line2D at 0x7bf4985ea920>,
#   <matplotlib.lines.Line2D at 0x7bf4985eada0>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x7bf4985e8700>],
#  'medians': [<matplotlib.lines.Line2D at 0x7bf4985ea2c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7bf497966c20>],
#  'means': [<matplotlib.lines.Line2D at 0x7bf497966a40>]}

# %%
df_source['ENERGYSTARScore'].isna().mean()
# Out:
# 0.2497037914691943

# %% [markdown]
# Nous imputons par la moyenne.

# %%
plt.boxplot(df_source['ENERGYSTARScore'].fillna(df_source['ENERGYSTARScore'].median()), labels=['ENERGYSTARScore'], showmeans=True, showfliers=True,patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7bf49709cca0>,
#   <matplotlib.lines.Line2D at 0x7bf49709c7c0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7bf49709d060>,
#   <matplotlib.lines.Line2D at 0x7bf49709c4f0>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x7bf49709c430>],
#  'medians': [<matplotlib.lines.Line2D at 0x7bf49709fa90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7bf49709c040>],
#  'means': [<matplotlib.lines.Line2D at 0x7bf49709d5a0>]}

# %%
D_star_1 = df_source['ENERGYSTARScore'].fillna(df_source['ENERGYSTARScore'].median()).copy()

# %% [markdown]
# ## Implementation in model

# %% [markdown]
# Testons la configuration 10b en variant sur la transformation de la nouvelle variable.

# %%
Feat_eng_dict = {
    'Featuring 10b': { # yeojohnson sur les plus important selon SHAP + normalisation latitude/longitude
        'std': [],
        'Minmax': [],
        'yeojohnson': ['RatioSteamUse', 'Storage', 'Office', 'Other', 'RatioElectricityUse', 'BuildingAge', 'NumberofFloors', 'Restaurant_hotel_health', 'PropertyGFABuilding(s)', 'NumberofBuildings']
    },
    'Featuring 10b1': { # yeojohnson sur les plus important selon SHAP + normalisation latitude/longitude
        'std': ['ENERGYSTARScore'],
        'Minmax': [],
        'yeojohnson': ['RatioSteamUse', 'Storage', 'Office', 'Other', 'RatioElectricityUse', 'BuildingAge', 'NumberofFloors', 'Restaurant_hotel_health', 'PropertyGFABuilding(s)', 'NumberofBuildings']
    },
    'Featuring 10b2': { # yeojohnson sur les plus important selon SHAP + normalisation latitude/longitude
        'std': [],
        'Minmax': ['ENERGYSTARScore'],
        'yeojohnson': [ 'RatioSteamUse', 'Storage', 'Office', 'Other', 'RatioElectricityUse', 'BuildingAge', 'NumberofFloors', 'Restaurant_hotel_health', 'PropertyGFABuilding(s)', 'NumberofBuildings']
    },
    'Featuring 10b3': { # yeojohnson sur les plus important selon SHAP + normalisation latitude/longitude
        'std': [],
        'Minmax': [],
        'yeojohnson': ['ENERGYSTARScore', 'RatioSteamUse', 'Storage', 'Office', 'Other', 'RatioElectricityUse', 'BuildingAge', 'NumberofFloors', 'Restaurant_hotel_health', 'PropertyGFABuilding(s)', 'NumberofBuildings']
    }
}

# %%
X = pd.concat([X, D_star_1], axis = 1, join='inner') # ajout de l'energystarscore

# %%
# normalisation de la target
y_copy = pd.Series(yeojohnson(y.copy())[0].reshape(1,-1)[0],name='SiteEnergyUseWN(kBtu)' ,index=y.index)

# autre process particuliers sur X :
X_copy = X.copy()
X_copy = X_copy.drop(Neighborhood + ['CouncilDistrictCode_1', 'Longitude', 'Latitude', 'RationNaturalGazUse'], axis = 1)
X_copy['RatioElectricityUse'] = X['RatioElectricityUse']/100
X_copy['RatioSteamUse'] = X['RatioSteamUse']/100

TABLE_5 = Cross_Val_Tab(model_, ('neg_root_mean_squared_error','r2'), Feat_eng_dict, X_copy, y_copy)
TABLE_5
# Out:
#                 neg_root_mean_squared_error        r2
# Featuring 10b                     -0.476504  0.618230
# Featuring 10b1                    -0.467900  0.631785
# Featuring 10b2                    -0.465115  0.636535
# Featuring 10b3                    -0.470486  0.627890

# %%
plt.bar(data= TABLE_5,
        x= TABLE_5.index,
        height='r2')
plt.xticks(rotation= 90)
plt.ylabel('r2 score')
plt.xlabel('ENERGYStarSCore transformation names')
plt.title('Mean CV scores including ENERGYStarScore')
c=-1
for i in TABLE_5.index:
  c+=1
  plt.text(x= c-.1,y= TABLE_5['r2'][i]+.01,s= round(TABLE_5['r2'][i], 4))

# %%
# normalisation de la target
y_copy = pd.Series(yeojohnson(y.copy())[0].reshape(1,-1)[0],name='SiteEnergyUseWN(kBtu)' ,index=y.index)

# autre process particuliers sur X :
X_copy = X.copy()
X_copy = X_copy.drop(Neighborhood + ['CouncilDistrictCode_1', 'Longitude', 'Latitude', 'RationNaturalGazUse'], axis = 1)
X_copy['RatioElectricityUse'] = X['RatioElectricityUse']/100
X_copy['RatioSteamUse'] = X['RatioSteamUse']/100
X_copy['ENERGYSTARScore'] = X['ENERGYSTARScore']/100

TABLE_5_2 = Cross_Val_Tab(model_, ('neg_root_mean_squared_error','r2'), Feat_eng_dict, X_copy, y_copy)
TABLE_5_2
# Out:
#                 neg_root_mean_squared_error        r2
# Featuring 10b                     -0.469255  0.630039
# Featuring 10b1                    -0.466864  0.633803
# Featuring 10b2                    -0.474164  0.621849
# Featuring 10b3                    -0.472459  0.625049

# %%
plt.bar(data= TABLE_5_2,
        x= TABLE_5_2.index,
        height='r2')
plt.xticks(rotation= 90)
plt.ylabel('r2 score')
plt.xlabel('ENERGYStarSCore transformation names')
plt.title('Mean CV scores including ENERGYStarScore')
c=-1
for i in TABLE_5_2.index:
  c+=1
  plt.text(x= c-.1,y= TABLE_5_2['r2'][i]+.01,s= round(TABLE_5_2['r2'][i], 4))

# %% [markdown]
# La configuration 10b2 avec division par 100 de l'Energystartscore donne le meilleur score.

# %%
# 10b2 + % ratio + std target + suppression des features après analyse VIF

# config 10b2
col_std, col_mM, col_yeo =  [],['ENERGYSTARScore'], [ 'RatioSteamUse', 'Storage', 'Office', 'Other', 'RatioElectricityUse', 'BuildingAge', 'NumberofFloors', 'Restaurant_hotel_health', 'PropertyGFABuilding(s)', 'NumberofBuildings']

# normalisation de la target
y_copy = pd.Series(yeojohnson(y.copy())[0].reshape(1,-1)[0],name='SiteEnergyUseWN(kBtu)' ,index=y.index)

# autre process particuliers sur X :
X_copy = X.copy()
X_copy = X_copy.drop(Neighborhood + ['CouncilDistrictCode_1', 'Longitude', 'Latitude', 'RationNaturalGazUse'], axis = 1)
X_copy['RatioElectricityUse'] = X['RatioElectricityUse']/100
X_copy['RatioSteamUse'] = X['RatioSteamUse']/100

X_train, X_test, y_train, y_test = preprocessing_tsf(col_std, col_mM, col_yeo, X=X_copy, y= y_copy)

# %%
model_.fit(X_train, y_train)
model_.score(X_test, y_test)
# Out:
# 0.698359528236574

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error

y_pred=model_.predict(X_test)#model_.predict(X.loc[y_test.index,:])
S1=pd.Series(y_pred.reshape(1,-1)[0])
S2=pd.Series(np.array(y_test).reshape(1,-1)[0])
pears=pd.concat([S1,S2], axis=1, ignore_index=True).corr().iloc[1,0]

sns.regplot(x=y_pred,y=np.array(y_test).reshape(1,-1)[0])
plt.xlabel('y_pred')
plt.ylabel('y_test')
plt.text(x=np.median(y_pred),y=np.median(y_test),s=f'R² = {str(round(pears,2))}')
# Out:
# Text(11.542962685965147, 11.537745299998889, 'R² = 0.84')

# %%
MSE = mean_squared_error(np.array(y_test).reshape(1,-1)[0],np.array(y_pred).reshape(1,-1)[0])
r2 = r2_score(np.array(y_test).reshape(1,-1)[0],np.array(y_pred).reshape(1,-1)[0])
MAPE = mean_absolute_percentage_error(np.array(y_test).reshape(1,-1)[0],np.array(y_pred).reshape(1,-1)[0])

print(f'r2_score : {round(r2,2)}\n',
      f'mean_absolute_percentage_error : {round(MAPE*100,2)} %\n',
      f'coef pearson btw predict and true : {round(pears,2)}')
# Out:
# r2_score : 0.7
#  mean_absolute_percentage_error : 2.64 %
#  coef pearson btw predict and true : 0.84

# %%
evaluation(model_,'model_')

# %% [markdown]
# Après insersion de la variables dans l'entraînement du modèle nous pouvons dire que celle-ci n'a pas une grande influence sur ses performances.
#
# L'EnergyStarscore n'est pas nécessairement pertiente au vu de la difficulté pour l'optenir.
